# %% [markdown]
# # Entrega Nº4
# ## Dataset Flights
# Javier Ceferino Rodriguez
# Maria Eva Ortega
# Julio Gonzalez
# Gonzalo Estevez
#
# ## Introduccion
#
# En el siguiente trabajo analizamos el dataset de vuelos con el objetivo de reforzar las trayectorias con mas demanda para lograr aumentar las ganancias y mejorar la experiencia de los pasajeros.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def read_dataset(file_name):
    """
    Lee un archivo csv y lo devuelve como un DataFrame
    """
    return pd.read_csv(file_name, index_col=0)

df = read_dataset('https://raw.githubusercontent.com/JaviCeRodriguez/Intro_Ciencia_Datos/main/Entregas/Entrega4/flights.csv')
df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1       2013      1    1     517.0             515        2.0     830.0
# 2       2013      1    1     533.0             529        4.0     850.0
# 3       2013      1    1     542.0             540        2.0     923.0
# 4       2013      1    1     544.0             545       -1.0    1004.0
# 5       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336772  2013      9   30       NaN            1455        NaN       NaN
# 336773  2013      9   30       NaN            2200        NaN       NaN
# 336774  2013      9   30       NaN            1210        NaN       NaN
# 336775  2013      9   30       NaN            1159        NaN       NaN
# 336776  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 1                  819       11.0      UA    1545  N14228    EWR  IAH
# 2                  830       20.0      UA    1714  N24211    LGA  IAH
# 3                  850       33.0      AA    1141  N619AA    JFK  MIA
# 4                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 5                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336772            1634        NaN      9E    3393     NaN    JFK  DCA
# 336773            2312        NaN      9E    3525     NaN    LGA  SYR
# 336774            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336775            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336776            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute            time_hour
# 1          227.0      1400     5      15  2013-01-01 05:00:00
# 2          227.0      1416     5      29  2013-01-01 05:00:00
# 3          160.0      1089     5      40  2013-01-01 05:00:00
# 4          183.0      1576     5      45  2013-01-01 05:00:00
# 5          116.0       762     6       0  2013-01-01 06:00:00
# ...          ...       ...   ...     ...                  ...
# 336772       NaN       213    14      55  2013-09-30 14:00:00
# 336773       NaN       198    22       0  2013-09-30 22:00:00
# 336774       NaN       764    12      10  2013-09-30 12:00:00
# 336775       NaN       419    11      59  2013-09-30 11:00:00
# 336776       NaN       431     8      40  2013-09-30 08:00:00
#
# [336776 rows x 19 columns]

# %%
#agregar grafico con cantidad de vuelos por aerolineas

# %% [markdown]
# A partir de lo observado en el gráfico anterior, vamos a enfocar nuestro análisis en el Carrier UA ya que es la aerolinea con la mayor cantidad de vuelos. Sin embargo este analisis sencillamente se podria aplicar al resto de las aerolineas de este dataset.

# %%
df_carrier_UA = df.loc[df['carrier'] == 'UA']
df_carrier_UA
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1       2013      1    1     517.0             515        2.0     830.0
# 2       2013      1    1     533.0             529        4.0     850.0
# 6       2013      1    1     554.0             558       -4.0     740.0
# 13      2013      1    1     558.0             600       -2.0     924.0
# 14      2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336724  2013      9   30    2052.0            2059       -7.0    2315.0
# 336729  2013      9   30    2055.0            2059       -4.0    2158.0
# 336738  2013      9   30    2105.0            2106       -1.0    2329.0
# 336756  2013      9   30    2149.0            2156       -7.0    2245.0
# 336763  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 1                  819       11.0      UA    1545  N14228    EWR  IAH
# 2                  830       20.0      UA    1714  N24211    LGA  IAH
# 6                  728       12.0      UA    1696  N39463    EWR  ORD
# 13                 917        7.0      UA     194  N29129    JFK  LAX
# 14                 937      -14.0      UA    1124  N53441    EWR  SFO
# ...                ...        ...     ...     ...     ...    ...  ...
# 336724            2358      -43.0      UA    1416  N68453    EWR  MCO
# 336729            2211      -13.0      UA    1066  N16701    EWR  BOS
# 336738            2354      -25.0      UA     475  N477UA    EWR  IAH
# 336756            2308      -23.0      UA     523  N813UA    EWR  BOS
# 336763              30       42.0      UA     471  N578UA    EWR  SFO
#
#         air_time  distance  hour  minute            time_hour
# 1          227.0      1400     5      15  2013-01-01 05:00:00
# 2          227.0      1416     5      29  2013-01-01 05:00:00
# 6          150.0       719     5      58  2013-01-01 05:00:00
# 13         345.0      2475     6       0  2013-01-01 06:00:00
# 14         361.0      2565     6       0  2013-01-01 06:00:00
# ...          ...       ...   ...     ...                  ...
# 336724     123.0       937    20      59  2013-09-30 20:00:00
# 336729      40.0       200    20      59  2013-09-30 20:00:00
# 336738     175.0      1400    21       6  2013-09-30 21:00:00
# 336756      37.0       200    21      56  2013-09-30 21:00:00
# 336763     318.0      2565    21      13  2013-09-30 21:00:00
#
# [58665 rows x 19 columns]

# %% [markdown]
# Visuaizacion del dataset filtrado por la aerolinea UA

# %% [markdown]
# Realizamos el siguiente gràfico para tener una primera aproximaciòn a la cantidad de vuelos distribuidos de acuerdo a los aeropuertos de origen.

# %%
#agregar title/axes
df_origin_UA = df_carrier_UA['origin'].value_counts()
df_origin_UA.plot(kind="bar")

# %% [markdown]
# Creamos una máscara para trabajar con las columnas que consideramos significativas para este anàlisis, en este caso las columanas de origen, destino y tiempo de demora entre vuelos.

# %%
df_mask_UA = df_carrier_UA[['origin', 'dest', 'dep_delay']]
df_mask_UA
# Out:
#        origin dest  dep_delay
# 1         EWR  IAH        2.0
# 2         LGA  IAH        4.0
# 6         EWR  ORD       -4.0
# 13        JFK  LAX       -2.0
# 14        EWR  SFO       -2.0
# ...       ...  ...        ...
# 336724    EWR  MCO       -7.0
# 336729    EWR  BOS       -4.0
# 336738    EWR  IAH       -1.0
# 336756    EWR  BOS       -7.0
# 336763    EWR  SFO       80.0
#
# [58665 rows x 3 columns]

# %% [markdown]
# Creamos una nueva tabla para poder observar la cantidad de vuelos en sus distintas trayectorias, ordenándolos de acuerdo a la cantidad de vuelos en forma descendente.

# %%
df_origin_dest = df_carrier_UA.groupby(['origin', 'dest'])['origin'].count().reset_index(name='count').sort_values(['count'], ascending=False)
df_origin_dest
# Out:
#    origin dest  count
# 41    EWR  SFO   4344
# 19    EWR  IAH   3973
# 30    EWR  ORD   3822
# 23    EWR  LAX   3764
# 4     EWR  BOS   3342
# 24    EWR  MCO   3217
# 52    LGA  ORD   3162
# 51    LGA  IAH   2951
# 48    JFK  SFO   2475
# 15    EWR  FLL   2407
# 11    EWR  DEN   2170
# 47    JFK  LAX   2059
# 22    EWR  LAS   2010
# 46    EWR  TPA   1968
# 31    EWR  PBI   1839
# 50    LGA  DEN   1626
# 8     EWR  CLE   1585
# 25    EWR  MIA   1565
# 37    EWR  SAN   1134
# 33    EWR  PHX   1120
# 40    EWR  SEA   1117
# 12    EWR  DFW   1094
# 36    EWR  RSW   1072
# 43    EWR  SNA    825
# 42    EWR  SJU    688
# 2     EWR  AUS    670
# 32    EWR  PDX    571
# 17    EWR  HNL    365
# 38    EWR  SAT    330
# 49    LGA  CLE    305
# 5     EWR  BQN    297
# 27    EWR  MSY    269
# 45    EWR  STT    189
# 14    EWR  EGE    110
# 1     EWR  ATL    103
# 6     EWR  BZN     36
# 21    EWR  JAC     23
# 28    EWR  MTJ     15
# 16    EWR  HDN     15
# 0     EWR  ANC      8
# 3     EWR  BDL      8
# 39    EWR  SDF      3
# 20    EWR  IND      3
# 34    EWR  PIT      2
# 29    EWR  OMA      2
# 44    EWR  STL      2
# 10    EWR  DCA      2
# 9     EWR  CLT      2
# 26    EWR  MSP      2
# 35    EWR  RDU      1
# 18    EWR  IAD      1
# 13    EWR  DTW      1
# 7     EWR  CHS      1

# %% [markdown]
# Realizamos un gráfico de barras para poder visualizar los datos de la tabla anterior. En este caso, establecimos un filtro para las trayectorias, entre un origen y un destino determinados, de más de mil vuelos.

# %%
# sns.set(rc = {'figure.figsize':(15,8)})
# sns.barplot(data=df_origin_dest, x='dest', y='count', stacked=True)
df_mask_vuelos = df_origin_dest[df_origin_dest['count'] > 1000]
ax = df_mask_vuelos.pivot_table(index='dest', columns='origin', values='count').plot.bar()
# for container in ax.containers:
#     ax.bar_label(container)

# %% [markdown]
# Importamos el dataset que contiene las especificaciones de cada avión a fin de realizar un análisis exploratorio para poder determinar las implicaciones en nuestro análisis.

# %%
df_planes = read_dataset('planes.csv')
df_planes
# Out:
#      tailnum    year                     type                   manufacturer  \
# 1     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 2     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 5     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3318  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3319  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3320  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3321  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3322  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
#           model  engines  seats  speed     engine
# 1     EMB-145XR        2     55    NaN  Turbo-fan
# 2      A320-214        2    182    NaN  Turbo-fan
# 3      A320-214        2    182    NaN  Turbo-fan
# 4      A320-214        2    182    NaN  Turbo-fan
# 5     EMB-145LR        2     55    NaN  Turbo-fan
# ...         ...      ...    ...    ...        ...
# 3318    717-200        2    100    NaN  Turbo-fan
# 3319      MD-88        2    142    NaN  Turbo-fan
# 3320    717-200        2    100    NaN  Turbo-fan
# 3321      MD-88        2    142    NaN  Turbo-jet
# 3322      MD-88        2    142    NaN  Turbo-jet
#
# [3322 rows x 9 columns]

# %%
df_joined = pd.merge(df_carrier_UA, df_planes, on='tailnum', how='inner')
df_joined
# Out:
#        year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0        2013      1    1     517.0             515        2.0     830.0
# 1        2013      1    8    1435.0            1440       -5.0    1717.0
# 2        2013      1    9     717.0             700       17.0     812.0
# 3        2013      1    9    1143.0            1144       -1.0    1425.0
# 4        2013      1   13     835.0             824       11.0    1030.0
# ...       ...    ...  ...       ...             ...        ...       ...
# 56967    2013      5   21    1313.0            1315       -2.0    1537.0
# 56968    2013      5   28    2216.0            1829      227.0      19.0
# 56969    2013      6    6    1847.0            1830       17.0    2207.0
# 56970    2013      6   25     950.0             930       20.0    1335.0
# 56971    2013      8   23     808.0             759        9.0    1053.0
#
#        sched_arr_time  arr_delay carrier  ...  minute            time_hour  \
# 0                 819       11.0      UA  ...      15  2013-01-01 05:00:00
# 1                1746      -29.0      UA  ...      40  2013-01-08 14:00:00
# 2                 815       -3.0      UA  ...       0  2013-01-09 07:00:00
# 3                1445      -20.0      UA  ...      44  2013-01-09 11:00:00
# 4                 951       39.0      UA  ...      24  2013-01-13 08:00:00
# ...               ...        ...     ...  ...     ...                  ...
# 56967            1538       -1.0      UA  ...      15  2013-05-21 13:00:00
# 56968            2114      185.0      UA  ...      29  2013-05-28 18:00:00
# 56969            2155       12.0      UA  ...      30  2013-06-06 18:00:00
# 56970            1242       53.0      UA  ...      30  2013-06-25 09:00:00
# 56971            1103      -10.0      UA  ...      59  2013-08-23 07:00:00
#
#        year_y                     type  manufacturer    model  engines  seats  \
# 0      1999.0  Fixed wing multi engine        BOEING  737-824        2    149
# 1      1999.0  Fixed wing multi engine        BOEING  737-824        2    149
# 2      1999.0  Fixed wing multi engine        BOEING  737-824        2    149
# 3      1999.0  Fixed wing multi engine        BOEING  737-824        2    149
# 4      1999.0  Fixed wing multi engine        BOEING  737-824        2    149
# ...       ...                      ...           ...      ...      ...    ...
# 56967  2012.0  Fixed wing multi engine        BOEING    787-8        2    260
# 56968  1992.0  Fixed wing multi engine        BOEING  767-322        2    330
# 56969  1997.0  Fixed wing multi engine        BOEING  777-222        2    400
# 56970  1992.0  Fixed wing multi engine        BOEING  767-322        2    330
# 56971  2002.0  Fixed wing multi engine        BOEING  777-222        2    400
#
#       speed     engine
# 0       NaN  Turbo-fan
# 1       NaN  Turbo-fan
# 2       NaN  Turbo-fan
# 3       NaN  Turbo-fan
# 4       NaN  Turbo-fan
# ...     ...        ...
# 56967   NaN  Turbo-fan
# 56968   NaN  Turbo-fan
# 56969   NaN  Turbo-fan
# 56970   NaN  Turbo-fan
# 56971   NaN  Turbo-fan
#
# [56972 rows x 27 columns]

# %%
df_joined["seats"].value_counts()
# Out:
# 149    19048
# 178    12837
# 200     9641
# 191     7558
# 179     6546
# 292      532
# 275      493
# 330      290
# 255       13
# 400        8
# 260        6
# Name: seats, dtype: int64

# %%
df_joined["engines"].value_counts()
# Out:
# 2    56972
# Name: engines, dtype: int64

# %%
df_joined["engine"].value_counts()
# Out:
# Turbo-fan    31676
# Turbo-jet    25296
# Name: engine, dtype: int64

# %%
df_joined["speed"].value_counts()
# Out:
# Series([], Name: speed, dtype: int64)

# %%
df_origin_dest_joined = df_joined.groupby(['origin', 'dest', 'seats'])['origin'].count().reset_index(name='count').sort_values(['count'], ascending=False)
df_origin_dest_joined
# Out:
#     origin dest  seats  count
# 192    JFK  SFO    178   2238
# 189    JFK  LAX    178   1936
# 162    EWR  SFO    149   1677
# 11     EWR  BOS    149   1461
# 204    LGA  IAH    149   1459
# ..     ...  ...    ...    ...
# 101    EWR  MIA    330      1
# 180    EWR  STL    200      1
# 53     EWR  IAD    149      1
# 112    EWR  OMA    149      1
# 197    LGA  CLE    178      1
#
# [212 rows x 4 columns]

# %%
# TODO: REVISAR VALORES DEL BARPLOT, NO ESTÁN TODOS O ESTÁN MAL

df_mask_vuelos_joined = df_origin_dest_joined[df_origin_dest_joined['count'] > 1200]
axj = df_mask_vuelos_joined.pivot_table(index='dest', columns='origin', values='count').plot.bar()
# for container in axj.containers:
#     axj.bar_label(container, padding=3, fontsize=16) # , fmt="%i")

# %%
df_origin_dest_joined[df_origin_dest_joined["count"] > 1400]
# Out:
#     origin dest  seats  count
# 192    JFK  SFO    178   2238
# 189    JFK  LAX    178   1936
# 162    EWR  SFO    149   1677
# 11     EWR  BOS    149   1461
# 204    LGA  IAH    149   1459
# 76     EWR  LAX    178   1439
